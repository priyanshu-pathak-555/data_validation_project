# %%
import pandas as pd 
import numpy as np

# %%
data= pd.read_csv('C:\\Users\\priya\\OneDrive\\Desktop\\computer_vsiosion_project\\data_validation_project\\PAN_DATA.csv')

# %%
data.head(5)
# Out:
#     Name    Age   Salary         PAN              Email
# 0   Aman   25.0  50000.0  DKQJD2673D     aman@gmail.com
# 1  Rohit   -5.0  60000.0  oiN4zAZyDF             rohit@
# 2  Priya  130.0 -10000.0  YQABN3510Y     priya@mail.com
# 3   Neha   40.0      NaN  kgEMEx6BvY  neha123@gmail.com
# 4    NaN   22.0  70000.0  LDYSG3590C                NaN

# %%
validated_data = pd.read_csv('C:\\Users\\priya\\OneDrive\\Desktop\\computer_vsiosion_project\\validated_data.csv')

# %%
validated_data.head(5)
# Out:
#     Name    Age   Salary         PAN              Email  PAN_valid  \
# 0   Aman   25.0  50000.0  DKQJD2673D     aman@gmail.com       True
# 1  Rohit   -5.0  60000.0  oiN4zAZyDF             rohit@      False
# 2  Priya  130.0 -10000.0  YQABN3510Y     priya@mail.com       True
# 3   Neha   40.0      NaN  kgEMEx6BvY  neha123@gmail.com      False
# 4    NaN   22.0  70000.0  LDYSG3590C                NaN       True
#
#    Email_valid  Age_valid  Salary_valid  Overall_Status  \
# 0         True       True          True            True
# 1        False      False          True           False
# 2         True      False         False           False
# 3         True       True         False           False
# 4        False       True          True           False
#
#                                     Errors
# 0                                      NaN
# 1  Invalid PAN, Invalid Email, Invalid Age
# 2              Invalid Age, Invalid Salary
# 3              Invalid PAN, Invalid Salary
# ...

# %%
invalid_data = pd.read_csv('C:\\Users\\priya\\OneDrive\\Desktop\\computer_vsiosion_project\\invalid_data.csv')

# %%
invalid_data.head(5)
# Out:
#    Unnamed: 0   Name    Age   Salary         PAN             Email  PAN_valid  \
# 0           0    NaN  130.0      NaN  PATED2424K  ppgcpo@gmail.com       True
# 1           1  Rohit   82.0 -10000.0  RYGQW2263R        test@gmail       True
# 2           2  Rohit   -5.0 -10000.0  FCSOK2712J  mdkgry@gmail.com       True
# 3           3  Priya  130.0      NaN  78zYyYWvBE              abc@      False
# 4           4  Rahul  130.0      NaN  LXQZW4807U  dwthym@gmail.com       True
#
#    Email_valid  Age_valid  Salary_valid  Overall_Status  \
# 0         True      False         False           False
# 1        False       True         False           False
# 2         True      False         False           False
# 3        False      False         False           False
# 4         True      False         False           False
#
#                                               Errors
# 0                        Invalid Age, Invalid Salary
# ...
